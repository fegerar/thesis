# %%
# !rm -rf thesis/
# !git clone https://github.com/fegerar/thesis
# !cd thesis && git switch vanilla-vqvae
# Out:
# Cloning into 'thesis'...
# remote: Enumerating objects: 172, done.
# remote: Counting objects: 100% (172/172), done.
# remote: Compressing objects: 100% (122/122), done.
# remote: Total 172 (delta 68), reused 148 (delta 44), pack-reused 0 (from 0)
# Receiving objects: 100% (172/172), 72.37 KiB | 12.06 MiB/s, done.
# Resolving deltas: 100% (68/68), done.
# Branch 'vanilla-vqvae' set up to track remote branch 'vanilla-vqvae' from 'origin'.
# Switched to a new branch 'vanilla-vqvae'

# %%
# !pip install gdown
# !gdown 1qnG7H2Ro1DdRBcBW7AYwHj9LPhA73uir
# Out:
# ...
# Downloading...
# From (original): https://drive.google.com/uc?id=1qnG7H2Ro1DdRBcBW7AYwHj9LPhA73uir
# From (redirected): https://drive.google.com/uc?id=1qnG7H2Ro1DdRBcBW7AYwHj9LPhA73uir&confirm=t&uuid=145f8eb4-d0f6-476e-8b8a-da0622a2256f
# To: /content/shapegraphs.pkl
# 100% 3.01G/3.01G [01:35<00:00, 31.7MB/s]

# %%
# !pip install -r thesis/requirements.txt
# Out:
# ...
#   Cloning https://github.com/fegerar/shapegraphs.git to /tmp/pip-req-build-5n82z995
#   Running command git clone --filter=blob:none --quiet https://github.com/fegerar/shapegraphs.git /tmp/pip-req-build-5n82z995
#   Resolved https://github.com/fegerar/shapegraphs.git to commit 87680a35aebbe01c285f021df6969e26a58c9286
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 4.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.7/63.7 kB 7.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 853.6/853.6 kB 58.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.8/78.8 kB 8.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 11.8 MB/s eta 0:00:0000:01:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 983.4/983.4 kB 70.2 MB/s eta 0:00:00
# ...

# %%
# !wandb login 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
# !python thesis/src/train_vqvae.py --config thesis/config/vqvae_default.yml
# Out:
# wandb: [wandb.login()] Using explicit session credentials for https://api.wandb.ai.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: W&B API key is configured. Use `wandb login --relogin` to force relogin
# Role vocabulary (26 roles): ['CAM', 'CB', 'CDM', 'CF', 'CM', 'GK', 'LAM', 'LB', 'LCB', 'LCDM', 'LCF', 'LCM', 'LDM', 'LF', 'LM', 'LW', 'RAM', 'RB', 'RCB', 'RCDM', 'RCF', 'RCM', 'RDM', 'RF', 'RM', 'RW']
# Node feature dim: 30
# Train: 442484 | Val: 55310 | Test: 55311
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# 💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
# ...
